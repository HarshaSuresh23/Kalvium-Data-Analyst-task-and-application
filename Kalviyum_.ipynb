# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshaSuresh23/Kalvium-Data-Analyst-task-and-application/blob/main/Kalviyum_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-1eeac748-5fcc-4eec-926a-405c27db665d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1eeac748-5fcc-4eec-926a-405c27db665d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory

# %%
# !chmod 600  ~/.kaggle/kaggle.json
# Out:
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
! kaggle datasets list
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/__init__.py", line 7, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/api/kaggle_api_extended.py", line 398, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
# !unzip "/content/gtsrb-german-traffic-sign.zip"

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

election_df=pd.read_csv('/content/election_results_2024.csv')
election_df.shape
# Out:
# (543, 8)

# %%
election_df.head()
# Out:
#        Constituency  Const. No.    Leading Candidate  \
# 0             AJMER          13  BHAGIRATH CHOUDHARY
# 1             ALWAR           8      BHUPENDER YADAV
# 2            AMBALA           1       VARUN CHAUDHRY
# 3  ANANTNAG-RAJOURI           3     MIAN ALTAF AHMAD
# 4         ARAKKONAM           7    S JAGATHRATCHAKAN
#
#                          Leading Party    Trailing Candidate  \
# 0               Bharatiya Janata Party  RAMCHANDRA CHOUDHARY
# 1               Bharatiya Janata Party           LALIT YADAV
# 2             Indian National Congress         BANTO KATARIA
# 3  Jammu & Kashmir National Conference        MEHBOOBA MUFTI
# 4            Dravida Munnetra Kazhagam             L VIJAYAN
#
#                              Trailing Party  Margin           Status
# 0                  Indian National Congress  329991  Result Declared
# 1                  Indian National Congress   48282  Result Declared
# ...

# %%
election_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543 entries, 0 to 542
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Constituency        543 non-null    object
#  1   Const. No.          543 non-null    int64
#  2   Leading Candidate   543 non-null    object
#  3   Leading Party       543 non-null    object
#  4   Trailing Candidate  542 non-null    object
#  5   Trailing Party      542 non-null    object
#  6   Margin              543 non-null    object
#  7   Status              543 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 34.1+ KB

# %%
election_df.isnull().sum()
# Out:
# Constituency          0
# Const. No.            0
# Leading Candidate     0
# Leading Party         0
# Trailing Candidate    1
# Trailing Party        1
# Margin                0
# Status                0
# dtype: int64

# %%
election_df = election_df[election_df['Constituency'].isna() == False]
election_df = election_df[election_df['Const. No.'].isna() == False]

# %%
election_df.describe()
# Out:
#        Const. No.
# count  543.000000
# mean    18.178637
# std     16.427840
# min      1.000000
# 25%      6.000000
# 50%     14.000000
# 75%     25.000000
# max     80.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Const. No.'].plot(kind='hist', bins=20, title='Const. No.')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['Const. No.'].plot(kind='line', figsize=(8, 4), title='Const. No.')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
elction_df()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-5f4638108f2a> in <cell line: 1>()
# ----> 1 elction_df()
#
# NameError: name 'elction_df' is not defined

# %%
election_df.tail()
# Out:
#          Constituency  Const. No.         Leading Candidate  \
# 538            Wardha           8       AMAR SHARADRAO KALE
# 539           Wayanad           4              RAHUL GANDHI
# 540        West Delhi           6        KAMALJEET SEHRAWAT
# 541  Yavatmal- Washim          14  SANJAY UTTAMRAO DESHMUKH
# 542         Zahirabad           5      SURESH KUMAR SHETKAR
#
#                                         Leading Party  \
# 538  Nationalist Congress Party – Sharadchandra Pawar
# 539                          Indian National Congress
# 540                            Bharatiya Janata Party
# 541             Shiv Sena (Uddhav Balasaheb Thackrey)
# 542                          Indian National Congress
#
#                     Trailing Candidate            Trailing Party  Margin  \
# 538           RAMDAS CHANDRABHAN TADAS    Bharatiya Janata Party   81648
# 539                         ANNIE RAJA  Communist Party of India  364422
# ...

# %%
import matplotlib.pyplot as plt


party_counts = election_df['Leading Party'].value_counts()

# Plot a pie chart
plt.figure(figsize=(10, 10))  # Adjust the figure size as needed
plt.pie(party_counts, autopct='%1.1f%%', startangle=140)
plt.title('Leading Party Distribution')
plt.show()

# %%
import matplotlib.pyplot as plt


party_counts = election_df['Leading Party'].value_counts()

# Plot a pie chart
plt.figure(figsize=(10, 10))  # Adjust the figure size as needed
plt.pie(party_counts, autopct='%1.1f%%', startangle=140)
plt.title('Leading Party Distribution')
plt.show()

# %%
import matplotlib.pyplot as plt


party_counts = election_df['Leading Party'].value_counts()

# Plot a pie chart
plt.figure(figsize=(10, 10))  # Adjust the figure size as needed
plt.pie(party_counts, autopct='%1.1f%%', startangle=140)
plt.title('Leading Party Distribution')
plt.show()

# %%
import matplotlib.pyplot as plt


party_counts = election_df['Leading Party'].value_counts()

# Plot a pie chart
plt.figure(figsize=(10, 10))  # Adjust the figure size as needed
plt.pie(party_counts, autopct='%1.1f%%', startangle=140)
plt.title('Leading Party Distribution')
plt.show()
